# %% [markdown]
# # Experiment 01: Baseline Axelrod Model
#
# Run the maintained baseline implementation from `src/axelrod/model.py` and save the standard figures to `results/figures/`.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
src_path = repo_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

print("Repository root:", repo_root)
print("Source path added:", src_path)

# %%
from axelrod.model import save_demo_outputs

outputs = save_demo_outputs(output_dir=repo_root / "results" / "figures")
outputs

# %% [markdown]
# # Experiment 04: Creator-Consumer Influence Planning
#
# **Status:** not implemented yet
#
# This notebook is currently a research planning notebook for a future MSc project stage. Creator-consumer influence dynamics have not been implemented yet.

# %% [markdown]
# ## Research Question
#
# How does asymmetric influence between creators and consumers affect convergence, clustering, and polarisation compared with the classical Axelrod baseline?

# %% [markdown]
# ## Hypothesis
#
# If some agents exert broader or stronger influence than others, cultural alignment may become more concentrated around influential actors, potentially increasing clustering or polarisation.

# %% [markdown]
# ## Planned Model Changes
#
# - Distinguish between creator and consumer agent roles.
# - Define how creators reach consumers and whether influence is directional.
# - Decide whether exposure is local, broadcast, or network-based.
# - Preserve the baseline similarity-based mechanism where appropriate.

# %% [markdown]
# ## Planned Metrics
#
# - Number of cultural domains
# - Alignment between consumers and creators
# - Polarisation or clustering measures
# - Largest-domain share
# - Active edges over time

# %% [markdown]
# ## TODO Checklist
#
# - [ ] Define creator-consumer roles
# - [ ] Specify influence direction and exposure rules
# - [ ] Choose first experimental scenario
# - [ ] Add comparison against the baseline model
# - [ ] Define polarisation-oriented metrics
# - [ ] Interpret whether asymmetry changes fragmentation patterns
